# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2 in /opt/conda/lib/python3.12/site-packages (from opencv-python) (2.2.6)
# Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 32.6 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
import os
import cv2
import json
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

class MotorcycleDataset(Dataset):
    def __init__(self, json_path, img_dir, transform=None, exclude_categories=None, target_size=(512, 512)):
        self.img_dir = img_dir
        self.transform = transform
        self.exclude_categories = exclude_categories if exclude_categories is not None else []
        self.target_size = target_size # 이미지 리사이즈를 위한 목표 크기 추가

        # 1. JSON 불러오기
        with open(json_path, 'r') as f:
            self.data = json.load(f)

        # 2. 이미지 정보와 어노테이션 매핑
        self.images = {img['id']: img for img in self.data['images']}
        self.img_ids = list(self.images.keys())

        # 3. 이미지 ID별로 어노테이션 그룹화
        self.annotations = {} 
        for ann in self.data['annotations']:
            img_id = ann['image_id']
            if img_id not in self.annotations:
                self.annotations[img_id] = []
            self.annotations[img_id].append(ann)

    def __len__(self):
        return len(self.img_ids)

    def __getitem__(self, idx):
        # 1. 이미지 로드
        img_id = self.img_ids[idx]
        file_name = self.images[img_id]['file_name']
        img_path = os.path.join(self.img_dir, file_name)
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        original_h, original_w = image.shape[0], image.shape[1]

        # 이미지 리사이즈
        if self.target_size is not None:
            image = cv2.resize(image, self.target_size, interpolation=cv2.INTER_AREA)
        
        # 2. 빈 마스크 생성 (리사이즈된 이미지와 동일한 크기)
        h, w = self.target_size if self.target_size is not None else (original_h, original_w)
        mask = np.zeros((h, w), dtype=np.uint8)

        # 3. 좌표 데이터를 마스크에 칠하기
        if img_id in self.annotations:
            for ann in self.annotations[img_id]:
                if ann.get('category_id') in self.exclude_categories:
                    continue

                for seg in ann['segmentation']:
                    if not isinstance(seg, list) or len(seg) < 6:
                        continue

                    poly = np.array(seg).reshape(-1, 2).astype(np.float32)
                    
                    # 원본 이미지 크기 대비 리사이즈 비율 적용하여 폴리곤 좌표 조정
                    scale_x = w / original_w
                    scale_y = h / original_h
                    poly[:, 0] = poly[:, 0] * scale_x
                    poly[:, 1] = poly[:, 1] * scale_y
                    poly = poly.astype(np.int32)

                    if len(poly) < 3:
                        continue

                    cv2.fillPoly(mask, [poly], 1)

        # 4. 파이토치 텐서로 변환
        image = torch.from_numpy(image).permute(2, 0, 1).float() / 255.0
        mask = torch.from_numpy(mask).long()

        return image, mask

# %%
json_path = "../motorcycle/Dataset/data.json"
images_path = "../motorcycle/Dataset/images"

# 'Undrivable' 카테고리 (ID: 1323880)를 제외하고 데이터셋 생성
exclude_category_ids = [1323880]
# 이미지 크기를 (512, 512)로 리사이즈하여 데이터셋 생성
dataset = MotorcycleDataset(json_path, images_path, exclude_categories=exclude_category_ids, target_size=(512, 512))
dataloader = DataLoader(dataset, batch_size=1, shuffle=True) # batch_size를 2에서 1로 줄였습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 # For drawing circles

# 1. 데이터셋에서 첫 번째 샘플 가져오기 (이미지 자체는 원본을 사용)
image, mask = dataset[0] # The image here is normalized [0,1] and tensor.
image_show = image.permute(1, 2, 0).numpy() # Convert to HWC, RGB, numpy array [0,1]
original_image_display = (image_show * 255).astype(np.uint8) # Convert back to 0-255 for cv2 operations and display
mask_show = mask.numpy() # mask_show 변수 정의 추가

# 2. 점 기반 시각화를 위한 이미지 복사
points_image = original_image_display.copy()

# 3. 첫 번째 이미지의 원본 어노테이션 데이터 가져오기
first_img_id = dataset.img_ids[0]
annotations_for_first_image = dataset.annotations.get(first_img_id, [])

# 4. 'Undrivable' 카테고리를 제외하고 점 그리기
exclude_category_id = 1323880 # Defined in the plan

for ann in annotations_for_first_image:
    if ann.get('category_id') == exclude_category_id:
        continue # 'Undrivable' 카테고리는 제외

    if 'segmentation' in ann and ann['segmentation']:
        for seg in ann['segmentation']:
            # COCO Segmentation 포맷은 [x1, y1, x2, y2, ...] 형태의 플랫 리스트
            # 유효한 폴리곤을 그려면 최소 3개의 점 (6개의 좌표)이 필요합니다.
            if not isinstance(seg, list) or len(seg) < 6:
                continue

            # 폴리곤 좌표를 (x, y) 쌍으로 변환
            # cv2.circle을 사용하기 위해 각 점에 대해 반복합니다.
            for i in range(0, len(seg), 2):
                x, y = int(seg[i]), int(seg[i+1])
                # 점을 빨간색으로 표시 (BGR 형식, cv2는 BGR을 사용)
                # cv2.circle(image, center, radius, color, thickness)
                cv2.circle(points_image, (x, y), 1, (0, 0, 255), -1) # radius 1, filled circle

# 5. 그래프 그리기
plt.figure(figsize=(20, 5))

# 원본 이미지
plt.subplot(1, 4, 1)
plt.title("Original Image")
plt.imshow(original_image_display) # Display original 0-255 image
plt.axis('off')

# 생성된 마스크 (정답)
plt.subplot(1, 4, 2)
plt.title("Segmentation Mask (Excluding Undrivable)")
plt.imshow(mask_show, cmap='gray')
plt.axis('off')

# 원본 위에 마스크 겹치기 (오버레이)
plt.subplot(1, 4, 3)
plt.title("Mask Overlay (Excluding Undrivable)")
plt.imshow(original_image_display) # Display original 0-255 image
plt.imshow(mask_show, alpha=0.5, cmap='jet') # alpha로 투명도 조절
plt.axis('off')

# 점 기반 시각화
plt.subplot(1, 4, 4)
plt.title("Point-based Visualization (Excluding Undrivable)")
# cv2.circle은 BGR로 그리기 때문에, matplotlib으로 표시하려면 RGB로 변환해야 함
plt.imshow(cv2.cvtColor(points_image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()

# %%
# !pip install segmentation_models_pytorch

import torch.nn as nn
import segmentation_models_pytorch as smp

# U-Net 선택.
model = smp.Unet(
    encoder_name="resnet18",        # 특징 추출기 (resnet34에서 resnet18로 변경하여 메모리 사용량 줄임)
    encoder_weights="imagenet",     # 사전 학습된 가중치 사용
    in_channels=3,                  # 입력 이미지 채널 (RGB)
    classes=6,                      # 출력 클래스 수 (PDF 설명서 기준 6개 클래스)
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device) # 모델을 GPU로 이동
print(device)
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting huggingface-hub>=0.24 (from segmentation_models_pytorch)
#   Downloading huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/lib/python3.12/site-packages (from segmentation_models_pytorch) (2.2.6)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from segmentation_models_pytorch) (11.2.1)
# Collecting safetensors>=0.3.1 (from segmentation_models_pytorch)
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting timm>=0.9 (from segmentation_models_pytorch)
#   Downloading timm-1.0.24-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch>=1.8 in /opt/conda/lib/python3.12/site-packages (from segmentation_models_pytorch) (2.7.1+cu118)
# Requirement already satisfied: torchvision>=0.9 in /opt/conda/lib/python3.12/site-packages (from segmentation_models_pytorch) (0.22.1+cu118)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.12/site-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.5.1)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub>=0.24->segmentation_models_pytorch)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Collecting shellingham (from huggingface-hub>=0.24->segmentation_models_pytorch)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface-hub>=0.24->segmentation_models_pytorch)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.14.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (4.9.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (0.16.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8->segmentation_models_pytorch) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.12/site-packages (from typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (8.2.1)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
# Downloading huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.3/553.3 kB 20.1 MB/s eta 0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 77.4 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading timm-1.0.24-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 108.6 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Installing collected packages: typer-slim, shellingham, safetensors, hf-xet, huggingface-hub, timm, segmentation_models_pytorch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [segmentation_models_pytorch]on_models_pytorch]
# Successfully installed hf-xet-1.2.0 huggingface-hub-1.4.1 safetensors-0.7.0 segmentation_models_pytorch-0.5.0 shellingham-1.5.4 timm-1.0.24 typer-slim-0.21.1
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/46.8M [00:00<?, ?B/s]
# cuda

# %%
import torch.optim as optim
from torch.amp import GradScaler # GradScaler import

# 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 모델의 가중치를 업데이트할 옵티마이저 (학습률 0.001)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# AMP GradScaler 초기화
scaler = GradScaler('cuda')

# %%
from torch.amp import autocast # autocast import

epochs = 10 # 전체 데이터를 몇 번 반복해서 학습할지

for epoch in range(epochs):
    model.train() # 모델을 학습 모드로 설정
    running_loss = 0.0

    # 각 epoch 시작 시 GPU 캐시 메모리 비우기
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    for images, masks in dataloader: # 아까 만든 데이터로더에서 묶음(Batch)씩 가져옴
        images = images.to(device)
        masks = masks.to(device)

        # 1. 경사(Gradient) 초기화
        optimizer.zero_grad()

        # 2. 모델 예측 (Forward) 및 오차 계산 (Loss) - autocast context manager 사용
        with autocast('cuda'): # mixed precision 활성화
            outputs = model(images)
            loss = criterion(outputs, masks)

        # 3. 역전파 (Backward) - GradScaler 사용
        scaler.scale(loss).backward() # loss를 스케일링하여 역전파

        # 4. 가중치 업데이트 (Step) - GradScaler 사용
        scaler.step(optimizer) # 스케일링된 그라디언트로 옵티마이저 업데이트
        scaler.update() # 다음 반복을 위해 스케일러 업데이트

        running_loss += loss.item()

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

print("학습 완료!")
# Out:
# Epoch [1/10], Loss: 0.1040
# Epoch [2/10], Loss: 0.0769
# Epoch [3/10], Loss: 0.0861
# Epoch [4/10], Loss: 0.0730
# Epoch [5/10], Loss: 0.0612
# Epoch [6/10], Loss: 0.0569
# Epoch [7/10], Loss: 0.0528
# Epoch [8/10], Loss: 0.0617
# Epoch [9/10], Loss: 0.0725
# Epoch [10/10], Loss: 0.0638
# 학습 완료!
